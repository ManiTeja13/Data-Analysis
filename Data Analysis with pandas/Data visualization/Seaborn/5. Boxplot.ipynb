# %% [markdown]
# # Box Plot
#
# - A box-plot is a very useful and standardized way of displaying the distribution of data based on a five-number summary (minimum, first quartile, second quartile(median), third quartile, maximum). It helps in understanding these parameters of the distribution of data and is extremely helpful in detecting outliers.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfmall = pd.read_csv("data\\supermarket_sales.csv")

# %%
dfmall
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#Detecting Outliers in Total feature

sns.boxplot(dfmall["Total"])
# Out:
# <AxesSubplot:>

# %%
#Horizontal representation

sns.boxplot(x = "Total", data= dfmall)
# Out:
# <AxesSubplot:xlabel='Total'>

# %%
#Width parameter is for the width of the box

sns.boxplot(x = "Total", data= dfmall, width=0.8)
# Out:
# <AxesSubplot:xlabel='Total'>

# %%
sns.boxplot(y = "Total", data= dfmall, width=0.3)
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
dfmall
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
dfmall["Payment"]
# Out:
# 0          Ewallet
# 1             Cash
# 2      Credit card
# 3          Ewallet
# 4          Ewallet
#           ...
# 995        Ewallet
# 996        Ewallet
# 997           Cash
# 998           Cash
# 999           Cash
# Name: Payment, Length: 1000, dtype: object

# %%
dfmall["Payment"].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
dfmall["Product line"]
# Out:
# 0           Health and beauty
# 1      Electronic accessories
# 2          Home and lifestyle
# 3           Health and beauty
# 4           Sports and travel
#                 ...
# 995         Health and beauty
# 996        Home and lifestyle
# 997        Food and beverages
# 998        Home and lifestyle
# 999       Fashion accessories
# Name: Product line, Length: 1000, dtype: object

# %%
dfmall["Product line"].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
dfmall["Total"]
# Out:
# 0       548.9715
# 1        80.2200
# 2       340.5255
# 3       489.0480
# 4       634.3785
#          ...
# 995      42.3675
# 996    1022.4900
# 997      33.4320
# 998      69.1110
# 999     649.2990
# Name: Total, Length: 1000, dtype: float64

# %%
dfmall["Payment"]
# Out:
# 0          Ewallet
# 1             Cash
# 2      Credit card
# 3          Ewallet
# 4          Ewallet
#           ...
# 995        Ewallet
# 996        Ewallet
# 997           Cash
# 998           Cash
# 999           Cash
# Name: Payment, Length: 1000, dtype: object

# %%
#Box plot for Total features by payment category 

sns.boxplot(x = "Payment", y = "Total", data = dfmall)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
dfmall
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#Using hue parameter

sns.boxplot(x = "Payment", y = "Total", data = dfmall, hue = "Gender")
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
#showmeans is a parameter which shows mean value in the plot

plt.figure(figsize=(16,8))
sns.boxplot(x = "Payment", y = "Total", data = dfmall, hue = "Gender", showmeans = True)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
#Using palette in Box plot

sns.boxplot(x = "Total", y = "Payment", data = dfmall, hue = "Gender", showmeans = True, palette='Spectral' )
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Payment'>

# %%
#Box plot for all numerical features in the dataframe

plt.style.use("ggplot")
plt.figure(figsize=(18,8))
sns.boxplot(data = dfmall)
# Out:
# <AxesSubplot:>
